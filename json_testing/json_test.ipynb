# %%
import pandas as pd
import unittest
import sys, os

# %%
df = pd.read_json('unit_test_combined.json', orient='records', lines=True)
df
# Out:
#              function_name                                             header  \
# 0             arrangeCoins  from math import sqrt\n\n\ndef arrangeCoins(n:...
# 1   findDelayedArrivalTime  \ndef findDelayedArrivalTime( arrivalTime: int...
# 2      findContentChildren  from typing import List\n\n\ndef findContentCh...
# 3            some_function           \ndef some_function( salary) -> float:\n
# 4                binaryGap                  \ndef binaryGap(n: int) -> int:\n
# ..                     ...                                                ...
# 95         swap_characters             \ndef swap_characters(string, i, j):\n
# 96        find_kth_largest                 \ndef find_kth_largest(nums, k):\n
# 97            count_primes                           \ndef count_primes(n):\n
# 98                 h_index                        \ndef h_index(citations):\n
# 99                 heapify                        \ndef heapify(arr, n, i):\n
#
# ...

# %%
headers = list(df['header'])
import json
headers_json = json.dumps(headers)
with open('headers.json', 'w') as fileout:
    fileout.write(headers_json)
